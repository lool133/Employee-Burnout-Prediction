# %% [markdown]
# # Employee Burnout Analysis

# %% [markdown]
# ## 1. Load Data
# Load the train and test CSV files.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# ## 2. Data Cleaning

# %%
train.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe32003000360033003200      2008-09-30  Female      Service
# 1      fffe3700360033003500      2008-11-30    Male      Service
# 2  fffe31003300320037003900      2008-03-10  Female      Product
# 3  fffe32003400380032003900      2008-11-03    Male      Service
# 4  fffe31003900340031003600      2008-07-24  Female      Service
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score  \
# 0                  No          2.0                  3.0                   3.8
# 1                 Yes          1.0                  2.0                   5.0
# 2                 Yes          2.0                  NaN                   5.8
# 3                 Yes          1.0                  1.0                   2.6
# 4                  No          3.0                  7.0                   6.9
#
#    Burn Rate
# 0       0.16
# 1       0.36
# 2       0.49
# 3       0.20
# 4       0.52

# %%
test.head()
# Out:
#                 Employee ID Date of Joining  Gender Company Type  \
# 0  fffe31003300390039003000      2008-12-10  Female      Service
# 1  fffe31003300310037003800      2008-08-14  Female      Product
# 2  fffe33003400380035003900      2008-11-13    Male      Product
# 3      fffe3100370039003200      2008-02-07  Female      Service
# 4  fffe32003600390036003700      2008-07-17  Female      Product
#
#   WFH Setup Available  Designation  Resource Allocation  Mental Fatigue Score
# 0                  No          2.0                  5.0                   7.7
# 1                 Yes          1.0                  2.0                   5.2
# 2                 Yes          1.0                  3.0                   5.9
# 3                  No          3.0                  6.0                   4.6
# 4                  No          2.0                  5.0                   6.4

# %%
train.shape
# Out:
# (22750, 9)

# %%
test.shape
# Out:
# (12250, 8)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Date of Joining       22750 non-null  object
#  2   Gender                22750 non-null  object
#  3   Company Type          22750 non-null  object
#  4   WFH Setup Available   22750 non-null  object
#  5   Designation           22750 non-null  float64
#  6   Resource Allocation   21369 non-null  float64
#  7   Mental Fatigue Score  20633 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           12250 non-null  object
#  1   Date of Joining       12250 non-null  object
#  2   Gender                12250 non-null  object
#  3   Company Type          12250 non-null  object
#  4   WFH Setup Available   12250 non-null  object
#  5   Designation           12250 non-null  float64
#  6   Resource Allocation   12250 non-null  float64
#  7   Mental Fatigue Score  12250 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 765.8+ KB

# %%
train.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  22750.000000         21369.000000          20633.000000  21626.000000
# mean       2.178725             4.481398              5.728188      0.452005
# std        1.135145             2.047211              1.920839      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
test.describe()
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score
# count  12250.000000         12250.000000          12250.000000
# mean       2.175265             4.458857              5.720571
# std        1.132885             2.045602              1.914063
# min        0.000000             1.000000              0.000000
# 25%        1.000000             3.000000              4.500000
# 50%        2.000000             4.000000              5.900000
# 75%        3.000000             6.000000              7.100000
# max        5.000000            10.000000             10.000000

# %% [markdown]
# ### Check Missing Values
# Display the count of missing values per column, sorted in descending order.

# %%
train.isnull().sum().sort_values(ascending=False)
# Out:
# Mental Fatigue Score    2117
# Resource Allocation     1381
# Burn Rate               1124
# Employee ID                0
# Date of Joining            0
# Gender                     0
# Company Type               0
# WFH Setup Available        0
# Designation                0
# dtype: int64

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# Employee ID             0
# Date of Joining         0
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# dtype: int64

# %% [markdown]
# ## 3. Handle Missing Values
# Fill missing values in `Resource Allocation` and `Mental Fatigue Score` with the median, and drop rows where `Burn Rate` (the target column) is missing.

# %%
train["Resource Allocation"] = train["Resource Allocation"].fillna(
    train["Resource Allocation"].median()
)

# %%
test["Resource Allocation"] = test["Resource Allocation"].fillna(
    train["Resource Allocation"].median()
)

# %%
train["Mental Fatigue Score"] = train["Mental Fatigue Score"].fillna(
    train["Mental Fatigue Score"].median()
)

# %%
test["Mental Fatigue Score"] = test["Mental Fatigue Score"].fillna(
    test["Mental Fatigue Score"].median()
)

# %%
train.dropna(subset=["Burn Rate"], inplace=True)

# %% [markdown]
# Confirm that all missing values have been handled.

# %%
train.isnull().sum()
# Out:
# Employee ID             0
# Date of Joining         0
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# Burn Rate               0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Employee ID             0
# Date of Joining         0
# Gender                  0
# Company Type            0
# WFH Setup Available     0
# Designation             0
# Resource Allocation     0
# Mental Fatigue Score    0
# dtype: int64

# %% [markdown]
# ## 4. Handle Duplicates
# Check for duplicate rows and remove them.

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 5. Feature Engineering
# Inspect the text (object) columns, and extract useful information from the `Date of Joining` column.

# %%
train.select_dtypes(include='object').columns
# Out:
# Index(['Employee ID', 'Date of Joining', 'Gender', 'Company Type',
#        'WFH Setup Available'],
#       dtype='object')

# %%
test.select_dtypes(include='object').columns
# Out:
# Index(['Employee ID', 'Date of Joining', 'Gender', 'Company Type',
#        'WFH Setup Available'],
#       dtype='object')

# %% [markdown]
# Check the data types again.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21626 entries, 0 to 22749
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           21626 non-null  object
#  1   Date of Joining       21626 non-null  object
#  2   Gender                21626 non-null  object
#  3   Company Type          21626 non-null  object
#  4   WFH Setup Available   21626 non-null  object
#  5   Designation           21626 non-null  float64
#  6   Resource Allocation   21626 non-null  float64
#  7   Mental Fatigue Score  21626 non-null  float64
#  8   Burn Rate             21626 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           12250 non-null  object
#  1   Date of Joining       12250 non-null  object
#  2   Gender                12250 non-null  object
#  3   Company Type          12250 non-null  object
#  4   WFH Setup Available   12250 non-null  object
#  5   Designation           12250 non-null  float64
#  6   Resource Allocation   12250 non-null  float64
#  7   Mental Fatigue Score  12250 non-null  float64
# dtypes: float64(3), object(5)
# memory usage: 765.8+ KB

# %% [markdown]
# Drop the `Employee ID` column since it's just an identifier with no predictive value.

# %%
train.drop("Employee ID", axis=1, inplace=True)

# %%
test.drop("Employee ID", axis=1, inplace=True)

# %% [markdown]
# Convert the `Date of Joining` column to datetime type.

# %%
train["Date of Joining"] = pd.to_datetime(train["Date of Joining"])

# %%
test["Date of Joining"] = pd.to_datetime(test["Date of Joining"])

# %% [markdown]
# Extract the year, month, and day from the joining date as separate columns.

# %%
train["Joining_Year"] = train["Date of Joining"].dt.year
train["Joining_Month"] = train["Date of Joining"].dt.month
train["Joining_Day"] = train["Date of Joining"].dt.day

# %%
test["Joining_Year"] = test["Date of Joining"].dt.year
test["Joining_Month"] = test["Date of Joining"].dt.month
test["Joining_Day"] = test["Date of Joining"].dt.day

# %% [markdown]
# Then drop the original date column since the useful information has already been extracted.

# %%
train.drop("Date of Joining", axis=1, inplace=True)

# %%
test.drop("Date of Joining", axis=1, inplace=True)

# %%
train.select_dtypes(include="object").columns
# Out:
# Index(['Gender', 'Company Type', 'WFH Setup Available'], dtype='object')

# %%
test.select_dtypes(include="object").columns
# Out:
# Index(['Gender', 'Company Type', 'WFH Setup Available'], dtype='object')

# %%
train.head()
# Out:
#    Gender Company Type WFH Setup Available  Designation  Resource Allocation  \
# 0  Female      Service                  No          2.0                  3.0
# 1    Male      Service                 Yes          1.0                  2.0
# 2  Female      Product                 Yes          2.0                  4.0
# 3    Male      Service                 Yes          1.0                  1.0
# 4  Female      Service                  No          3.0                  7.0
#
#    Mental Fatigue Score  Burn Rate  Joining_Year  Joining_Month  Joining_Day
# 0                   3.8       0.16          2008              9           30
# 1                   5.0       0.36          2008             11           30
# 2                   5.8       0.49          2008              3           10
# 3                   2.6       0.20          2008             11            3
# 4                   6.9       0.52          2008              7           24

# %%
test.head()
# Out:
#    Gender Company Type WFH Setup Available  Designation  Resource Allocation  \
# 0  Female      Service                  No          2.0                  5.0
# 1  Female      Product                 Yes          1.0                  2.0
# 2    Male      Product                 Yes          1.0                  3.0
# 3  Female      Service                  No          3.0                  6.0
# 4  Female      Product                  No          2.0                  5.0
#
#    Mental Fatigue Score  Joining_Year  Joining_Month  Joining_Day
# 0                   7.7          2008             12           10
# 1                   5.2          2008              8           14
# 2                   5.9          2008             11           13
# 3                   4.6          2008              2            7
# 4                   6.4          2008              7           17

# %% [markdown]
# #7. EDA

# %%
print(train.columns.tolist())
# Out:
# ['Gender', 'Company Type', 'WFH Setup Available', 'Designation', 'Resource Allocation', 'Mental Fatigue Score', 'Burn Rate', 'Joining_Year', 'Joining_Month', 'Joining_Day']

# %%
print(test.columns.tolist())
# Out:
# ['Gender', 'Company Type', 'WFH Setup Available', 'Designation', 'Resource Allocation', 'Mental Fatigue Score', 'Joining_Year', 'Joining_Month', 'Joining_Day']

# %%
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (8,5)
plt.rcParams["font.size"] = 12

# %%
plt.figure(figsize=(6,6))

train.Gender.value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90,
    colors=["#66b3ff","#ff9999"]
)

plt.ylabel("")
plt.title("Gender Distribution")
plt.show()

# %%
sns.countplot(data=train,x="Company Type",palette="Set2")

plt.title("Company Type Distribution")
plt.show()
# Out:
# C:\Users\tiger\AppData\Local\Temp\ipykernel_13268\332083962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train,x="Company Type",palette="Set2")

# %%
sns.countplot(data=train,x="WFH Setup Available",palette="Set1")

plt.title("WFH Availability")
plt.show()
# Out:
# C:\Users\tiger\AppData\Local\Temp\ipykernel_13268\569764193.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train,x="WFH Setup Available",palette="Set1")

# %%
sns.histplot(
    train["Designation"],
    bins=10,
    kde=True,
    color="purple"
)

plt.title("Designation Distribution")
plt.show()

# %%
sns.histplot(
    train["Resource Allocation"],
    kde=True,
    color="green"
)

plt.title("Resource Allocation")
plt.show()

# %%
sns.histplot(
    train["Mental Fatigue Score"],
    kde=True,
    color="orange"
)

plt.title("Mental Fatigue Score")
plt.show()

# %%
sns.histplot(
    train["Burn Rate"],
    kde=True,
    color="red"
)

plt.title("Burn Rate Distribution")
plt.show()

# %%
sns.boxplot(
    data=train,
    x="Gender",
    y="Burn Rate",
    palette="pastel"
)

plt.title("Burn Rate by Gender")
plt.show()
# Out:
# C:\Users\tiger\AppData\Local\Temp\ipykernel_13268\2249702177.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
sns.boxplot(
    data=train,
    x="Company Type",
    y="Burn Rate"
)

plt.show()

# %%
sns.boxplot(
    data=train,
    x="WFH Setup Available",
    y="Burn Rate"
)

plt.show()

# %%
sns.scatterplot(
    data=train,
    x="Mental Fatigue Score",
    y="Burn Rate",
    alpha=0.6
)

plt.show()

# %%
sns.scatterplot(
    data=train,
    x="Resource Allocation",
    y="Burn Rate",
    alpha=0.6
)

plt.show()

# %%
sns.boxplot(
    data=train,
    x="Designation",
    y="Burn Rate"
)

plt.show()

# %%
plt.figure(figsize=(8,6))

corr = train.corr(numeric_only=True)

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(
    train[
        [
            "Designation",
            "Resource Allocation",
            "Mental Fatigue Score",
            "Burn Rate"
        ]
    ]
)

# %% [markdown]
# #8. Data Preprocessing

# %%
X_train = train.drop("Burn Rate", axis=1)
y_train = train["Burn Rate"]

# %%
X_train
# Out:
#        Gender Company Type WFH Setup Available  Designation  \
# 0      Female      Service                  No          2.0
# 1        Male      Service                 Yes          1.0
# 2      Female      Product                 Yes          2.0
# 3        Male      Service                 Yes          1.0
# 4      Female      Service                  No          3.0
# ...       ...          ...                 ...          ...
# 22745  Female      Service                  No          1.0
# 22746  Female      Product                 Yes          3.0
# 22747    Male      Service                 Yes          3.0
# 22748  Female      Service                  No          2.0
# 22749    Male      Product                  No          3.0
#
#        Resource Allocation  Mental Fatigue Score  Joining_Year  Joining_Month  \
# 0                      3.0                   3.8          2008              9
# 1                      2.0                   5.0          2008             11
# 2                      4.0                   5.8          2008              3
# 3                      1.0                   2.6          2008             11
# 4                      7.0                   6.9          2008              7
# ...                    ...                   ...           ...            ...
# 22745                  3.0                   5.9          2008             12
# 22746                  6.0                   6.7          2008              1
# 22747                  7.0                   5.9          2008             11
# 22748                  5.0                   5.9          2008              1
# 22749                  6.0                   7.8          2008              1
#
#        Joining_Day
# 0               30
# 1               30
# 2               10
# 3                3
# 4               24
# ...            ...
# 22745           30
# 22746           19
# 22747            5
# 22748           10
# 22749            6
#
# [21626 rows x 9 columns]

# %%
y_train
# Out:
# 0        0.16
# 1        0.36
# 2        0.49
# 3        0.20
# 4        0.52
#          ...
# 22745    0.41
# 22746    0.59
# 22747    0.72
# 22748    0.52
# 22749    0.61
# Name: Burn Rate, Length: 21626, dtype: float64

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train,
    y_train,
    test_size=0.2,
    random_state=42
)

# %%
X_test = test.copy()

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(X_valid.shape)
# Out:
# (17300, 9)
# (17300,)
# (12250, 9)
# (4326, 9)

# %%
numerical_features = X_train.select_dtypes(include=["int", "float"]).columns.tolist()
numerical_features
# Out:
# ['Designation',
#  'Resource Allocation',
#  'Mental Fatigue Score',
#  'Joining_Year',
#  'Joining_Month',
#  'Joining_Day']

# %%
categorical_features = X_train.select_dtypes(include=['object', 'category']).columns.tolist()

categorical_features
# Out:
# ['Gender', 'Company Type', 'WFH Setup Available']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_features),
        ("Cag", OneHotEncoder(), categorical_features)
    ]
)

# %% [markdown]
# # XGboost

# %%
pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", XGBRegressor(
        objective="reg:squarederror",
        n_estimators=500,
        learning_rate=0.01,
        max_depth=8,
        subsample=0.9,
        colsample_bytree=0.9,
        min_child_weight=1,
        gamma=0,
        reg_alpha=0.1,
        reg_lambda=1.5,
        random_state=42,
        n_jobs=-1
    ))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Designation',
#                                                    'Resource Allocation',
#                                                    'Mental Fatigue Score',
#                                                    'Joining_Year',
#                                                    'Joining_Month',
#                                                    'Joining_Day']),
#                                                  ('Cag', OneHotEncoder(),
#                                                   ['Gender', 'Company Type',
#                                                    'WFH Setup Available'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=No...
#                               feature_types=None, feature_weights=None, gamma=0,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=0.01,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=8, max_leaves=None, min_child_weight=1,
#                               missing=nan, monotone_constraints=None,
#                               multi_strategy=None, n_estimators=500, n_jobs=-1,
#                               num_parallel_tree=None, ...))])

# %%
y_pred = pipeline.predict(X_valid)

# %%
print(f"R² Score : {r2_score(y_valid, y_pred):.4f}")
print(f"MAE      : {mean_absolute_error(y_valid, y_pred):.4f}")
print(f"MSE      : {mean_squared_error(y_valid, y_pred):.4f}")
print(f"RMSE     : {np.sqrt(mean_squared_error(y_valid, y_pred)):.4f}")
# Out:
# R² Score : 0.9052
# MAE      : 0.0471
# MSE      : 0.0036
# RMSE     : 0.0601

# %%
X = train.drop("Burn Rate", axis=1)
y = train["Burn Rate"]

pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Designation',
#                                                    'Resource Allocation',
#                                                    'Mental Fatigue Score',
#                                                    'Joining_Year',
#                                                    'Joining_Month',
#                                                    'Joining_Day']),
#                                                  ('Cag', OneHotEncoder(),
#                                                   ['Gender', 'Company Type',
#                                                    'WFH Setup Available'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=No...
#                               feature_types=None, feature_weights=None, gamma=0,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=0.01,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=8, max_leaves=None, min_child_weight=1,
#                               missing=nan, monotone_constraints=None,
#                               multi_strategy=None, n_estimators=500, n_jobs=-1,
#                               num_parallel_tree=None, ...))])

# %%
predictions = pipeline.predict(test)

# %%
submission = pd.DataFrame({
    "Burn Rate": predictions
})

submission.to_csv("submission.csv", index=False)

# %%
df=pd.read_csv("submission.csv")

# %%
df.head()
# Out:
#    Burn Rate
# 0   0.613713
# 1   0.354822
# 2   0.379329
# 3   0.391524
# 4   0.527257

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_valid, y_pred)
plt.plot([y_valid.min(), y_valid.max()],
         [y_valid.min(), y_valid.max()],
         'r--')

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %%
residuals = y_valid - y_pred

plt.figure(figsize=(6,6))
plt.scatter(y_pred, residuals)
plt.axhline(y=0, linestyle='--')

plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
import joblib

joblib.dump(pipeline, "burnout_model.pkl")
# Out:
# ['burnout_model.pkl']
